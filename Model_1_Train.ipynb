# %% [markdown]
# # Importing the necessary libraries and dependencies

# %%
# Download Spacy Model for Tokenization
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 5.6 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/12.8 MB 7.5 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.5/12.8 MB 10.5 MB/s eta 0:00:01
#      ------------------------- -------------- 8.1/12.8 MB 11.2 MB/s eta 0:00:01
#      --------------------------------- ----- 11.0/12.8 MB 11.9 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 11.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import json
from sklearn.metrics import classification_report
from utils.preprocessing import DOCRED_Processing # imported from preprocessing.py
import utils.train as train # imported from train.py

# %% [markdown]
# # Loading the training file

# %%
with open("./dataset_DocRED/train_annotated.json", "r") as f:
    train_Dataset = json.load(f)

train_Dataset = DOCRED_Processing(train_Dataset)
train_Dataset.df.head()
# Out:
#               entity1       entity2  original_doc  \
# 0  Zest Airways, Inc.    Pasay City  AirAsia Zest
# 2            Zest Air   Philippines  AirAsia Zest
# 3          Pasay City   Philippines  AirAsia Zest
# 4          Pasay City  Metro Manila  AirAsia Zest
# 5         Philippines  Metro Manila  AirAsia Zest
#
#                                          sent_tokens  \
# 0  [Zest, Airways, ,, Inc., operated, as, AirAsia...
# 2  [Less, than, a, year, after, AirAsia, and, Zes...
# 3  [Zest, Airways, ,, Inc., operated, as, AirAsia...
# 4  [Zest, Airways, ,, Inc., operated, as, AirAsia...
# 5  [Zest, Airways, ,, Inc., operated, as, AirAsia...
#
#                                             sentence  \
# 0  Zest Airways , Inc. operated as AirAsia Zest (...
# 2   Less than a year after AirAsia and Zest Air '...
# 3  Zest Airways , Inc. operated as AirAsia Zest (...
# 4  Zest Airways , Inc. operated as AirAsia Zest (...
# 5  Zest Airways , Inc. operated as AirAsia Zest (...
#
#                                            relation entity1_span entity2_span
# 0                             headquarters location    [0, 1, 3]     [31, 32]
# 2                                           country       [7, 8]         [28]
# 3                                           country     [31, 32]         [38]
# 4  located in the administrative territorial entity     [31, 32]     [34, 35]
# 5        contains administrative territorial entity         [38]     [34, 35]

# %%
# X and Y preparation for training data
X_train = train_Dataset.df.drop(['sent_tokens', 'relation'], axis=1)
Y_train= train_Dataset.df['relation']

# %% [markdown]
# # Loading the testing file

# %%
with open("./dataset_DocRED/dev.json", "r") as f:
    test_Dataset = json.load(f)

test_Dataset = DOCRED_Processing(test_Dataset)
test_Dataset.df.head()
# Out:
#       entity1     entity2 original_doc  \
# 0     Piraeus      Greece      Skai TV
# 1  Skai Group      Greece      Skai TV
# 2      Athens      Greece      Skai TV
# 3     Skai TV     Piraeus      Skai TV
# 4     Skai TV  Skai Group      Skai TV
#
#                                          sent_tokens  \
# 0  [Skai, TV, is, a, Greek, free, -, to, -, air, ...
# 1  [Skai, TV, is, a, Greek, free, -, to, -, air, ...
# 2  [Skai, TV, is, a, Greek, free, -, to, -, air, ...
# 3  [Skai, TV, is, a, Greek, free, -, to, -, air, ...
# 4  [Skai, TV, is, a, Greek, free, -, to, -, air, ...
#
#                                             sentence               relation  \
# 0   Skai TV is a Greek free - to - air television...                country
# 1   Skai TV is a Greek free - to - air television...                country
# 2   Skai TV is a Greek free - to - air television...                country
# 3  Skai TV is a Greek free - to - air television ...  headquarters location
# 4   Skai TV is a Greek free - to - air television...               owned by
#
#   entity1_span entity2_span
# 0         [14]         [36]
# 1      [0, 22]         [54]
# 2         [30]         [61]
# 3       [0, 1]         [14]
# 4       [0, 1]      [0, 22]

# %%
# X and Y preparation for testing data
X_test = test_Dataset.df.drop(['sent_tokens', 'relation'], axis=1)
Y_test = test_Dataset.df['relation']

# %% [markdown]
# # Train model

# %%
model = train.train_function(X_train, Y_train)

# %% [markdown]
# # Printing classification report
#
# 1. Train Dataset

# %%
Y_pred_train = model.predict(X_train)
print(classification_report(Y_train, Y_pred_train))
# Out:
#                                                   precision    recall  f1-score   support
#
#                          applies to jurisdiction       0.88      0.17      0.28       271
#                                           author       0.92      0.65      0.77       300
#                                   award received       0.99      0.67      0.80       161
#                                    basin country       1.00      0.16      0.27        82
#                                          capital       1.00      0.06      0.11        72
#                                       capital of       1.00      0.02      0.03        62
#                                      cast member       0.90      0.82      0.86       551
#                                      chairperson       0.92      0.20      0.33        59
#                                       characters       0.95      0.56      0.70       149
#                                            child       0.64      0.34      0.45       355
#                                         composer       0.87      0.54      0.67        74
#                                         conflict       0.90      0.85      0.87       265
#       contains administrative territorial entity       0.93      0.17      0.29      1900
#                                        continent       0.80      0.87      0.84       337
#                                          country       0.40      0.99      0.57      8229
#                           country of citizenship       0.79      0.65      0.71      2354
#                                country of origin       0.86      0.40      0.55       481
#                                          creator       0.82      0.60      0.69       214
#                                    date of birth       0.97      0.99      0.98      1018
#                                    date of death       1.00      0.96      0.98       786
#                                        developer       0.71      0.54      0.61       230
#                                         director       0.75      0.51      0.61       230
#               dissolved, abolished or demolished       0.95      0.92      0.93        76
#                                      educated at       0.95      0.71      0.81       283
#                                         employer       0.98      0.60      0.75       191
#                                         end time       0.93      0.57      0.71        47
#                                     ethnic group       1.00      0.05      0.09        62
#                                           father       0.93      0.16      0.27       269
#                                      followed by       0.93      0.55      0.69       190
#                                          follows       0.93      0.54      0.68       185
#                                       founded by       1.00      0.22      0.36        86
#                                            genre       0.99      0.61      0.75       108
#                                         has part       0.86      0.46      0.60       583
#                               head of government       0.86      0.31      0.46       181
#                                    head of state       1.00      0.21      0.34       125
#                            headquarters location       0.89      0.09      0.17       253
#                                        inception       0.97      0.98      0.97       434
#                                    influenced by       1.00      0.22      0.36         9
#                                      instance of       0.86      0.32      0.46        98
#              languages spoken, written or signed       0.87      0.19      0.31       145
#                                           league       0.98      0.51      0.67       174
#                                 legislative body       1.00      0.19      0.32       148
#              located in or next to body of water       0.80      0.53      0.63       192
# located in the administrative territorial entity       0.79      0.20      0.32      4012
#                       located on terrain feature       0.77      0.15      0.25       136
#                                         location       0.93      0.43      0.58       162
#                            location of formation       1.00      0.09      0.16        57
#                                        lyrics by       0.81      0.38      0.52        34
#                                     manufacturer       0.89      0.55      0.68        76
#                                        member of       0.95      0.40      0.57       384
#                        member of political party       0.99      0.48      0.65       384
#                            member of sports team       0.96      0.67      0.79       330
#                                  military branch       0.98      0.41      0.58       102
#                                           mother       0.93      0.19      0.31        70
#                         mouth of the watercourse       1.00      0.32      0.48        91
#                               narrative location       1.00      0.29      0.44        42
#                                     notable work       0.97      0.48      0.64       146
#                                official language       0.77      0.12      0.22        80
#                                         operator       0.80      0.36      0.50        89
#                        original language of work       1.00      0.39      0.56        62
#                                 original network       0.91      0.41      0.57       151
#                                         owned by       0.61      0.38      0.47       200
#                              parent organization       0.73      0.18      0.29        89
#                                     parent taxon       1.00      0.21      0.35        71
#                                          part of       0.85      0.47      0.61       573
#                                      participant       0.98      0.64      0.78       171
#                                   participant of       1.00      0.76      0.86       215
#                                        performer       0.88      0.67      0.76      1019
#                                   place of birth       0.82      0.15      0.25       447
#                                   place of death       1.00      0.14      0.24       170
#                                         platform       0.94      0.85      0.89       273
#                                    point in time       0.86      0.93      0.89        96
#                                    position held       1.00      0.23      0.37        22
#                                  present in work       0.88      0.74      0.80       281
#                                         producer       0.95      0.33      0.49       110
#                     product or material produced       1.00      0.14      0.24        36
#                               production company       0.97      0.48      0.64        79
#                                 publication date       0.99      0.99      0.99      1111
#                                        publisher       0.88      0.41      0.56       159
#                                     record label       0.96      0.75      0.84       548
#                                         religion       0.92      0.36      0.52       131
#                                      replaced by       0.90      0.26      0.40        35
#                                         replaces       1.00      0.12      0.22        16
#                                        residence       1.00      0.10      0.18        30
#                                     screenwriter       0.83      0.41      0.55       142
#                                   separated from       0.00      0.00      0.00         2
#                                           series       0.97      0.61      0.75       138
#                                          sibling       0.84      0.51      0.64       325
#                                      sister city       0.00      0.00      0.00         4
#                                           spouse       0.85      0.40      0.54       296
#                                       start time       0.83      0.81      0.82       107
#                                      subclass of       1.00      0.28      0.44        57
#                                       subsidiary       1.00      0.37      0.54        90
#                             territory claimed by       0.93      0.50      0.65        26
#                                unemployment rate       0.00      0.00      0.00         1
#                                    work location       0.81      0.26      0.40        99
#
#                                         accuracy                           0.61     35596
#                                        macro avg       0.88      0.43      0.53     35596
#                                     weighted avg       0.77      0.61      0.59     35596
# c:\Users\chira\anaconda3\envs\docred\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\chira\anaconda3\envs\docred\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\chira\anaconda3\envs\docred\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# 2. Test Dataset

# %%
Y_pred_test = model.predict(X_test)
print(classification_report(Y_test, Y_pred_test))
# Out:
#                                                   precision    recall  f1-score   support
#
#                          applies to jurisdiction       0.00      0.00      0.00        67
#                                           author       0.36      0.06      0.10        88
#                                   award received       0.50      0.02      0.03        61
#                                    basin country       0.00      0.00      0.00        30
#                                          capital       0.00      0.00      0.00        25
#                                       capital of       0.00      0.00      0.00        19
#                                      cast member       0.69      0.21      0.32       168
#                                      chairperson       0.00      0.00      0.00        20
#                                       characters       0.00      0.00      0.00        71
#                                            child       0.00      0.00      0.00        77
#                                         composer       0.00      0.00      0.00        54
#                                         conflict       0.70      0.58      0.64       106
#       contains administrative territorial entity       0.76      0.05      0.09       591
#                                        continent       0.71      0.21      0.32       105
#                                          country       0.29      0.99      0.44      2611
#                           country of citizenship       0.42      0.23      0.29       696
#                                country of origin       0.91      0.05      0.10       184
#                                          creator       0.00      0.00      0.00        39
#                                    date of birth       0.76      0.88      0.81       338
#                                    date of death       0.74      0.60      0.67       248
#                                        developer       0.50      0.03      0.05        73
#                                         director       0.33      0.05      0.09        81
#               dissolved, abolished or demolished       1.00      0.03      0.06        35
#                                      educated at       0.49      0.43      0.46        83
#                                         employer       0.38      0.06      0.10        50
#                                         end time       0.00      0.00      0.00        22
#                                     ethnic group       0.00      0.00      0.00        26
#                                           father       0.00      0.00      0.00        56
#                                      followed by       0.33      0.06      0.10        49
#                                          follows       0.83      0.08      0.14        66
#                                       founded by       0.00      0.00      0.00        23
#                                            genre       0.00      0.00      0.00        11
#                                         has part       1.00      0.02      0.03       170
#                               head of government       0.75      0.07      0.14        40
#                                    head of state       0.00      0.00      0.00        48
#                            headquarters location       0.00      0.00      0.00        81
#                                        inception       0.63      0.77      0.69       137
#                                    influenced by       0.00      0.00      0.00         8
#                                      instance of       0.00      0.00      0.00        45
#              languages spoken, written or signed       0.00      0.00      0.00        44
#                                           league       0.00      0.00      0.00        55
#                                 legislative body       0.00      0.00      0.00        48
#              located in or next to body of water       0.00      0.00      0.00        78
# located in the administrative territorial entity       0.45      0.03      0.05      1204
#                       located on terrain feature       0.00      0.00      0.00        57
#                                         location       0.55      0.08      0.15        71
#                            location of formation       0.00      0.00      0.00        13
#                                        lyrics by       0.00      0.00      0.00         7
#                                     manufacturer       0.50      0.03      0.05        39
#                                        member of       1.00      0.02      0.04       109
#                        member of political party       0.00      0.00      0.00        96
#                            member of sports team       0.93      0.09      0.17       152
#                                  military branch       0.00      0.00      0.00        39
#                                           mother       0.00      0.00      0.00        14
#                         mouth of the watercourse       0.00      0.00      0.00        33
#                               narrative location       0.00      0.00      0.00        14
#                                     notable work       0.00      0.00      0.00        55
#                                official language       0.00      0.00      0.00        36
#                                         operator       0.00      0.00      0.00        39
#                        original language of work       0.00      0.00      0.00        28
#                                 original network       0.00      0.00      0.00        38
#                                         owned by       0.00      0.00      0.00        73
#                              parent organization       0.00      0.00      0.00        39
#                                     parent taxon       0.00      0.00      0.00        17
#                                          part of       0.62      0.12      0.21       185
#                                      participant       0.95      0.39      0.55        49
#                                   participant of       0.96      0.53      0.68        51
#                                        performer       0.51      0.18      0.26       327
#                                   place of birth       0.00      0.00      0.00       131
#                                   place of death       0.00      0.00      0.00        45
#                                         platform       0.91      0.43      0.58        68
#                                    point in time       0.43      0.28      0.34        36
#                                    position held       0.00      0.00      0.00         8
#                                  present in work       0.00      0.00      0.00       114
#                                         producer       0.00      0.00      0.00        44
#                     product or material produced       0.00      0.00      0.00         9
#                               production company       0.00      0.00      0.00        34
#                                 publication date       0.88      0.93      0.90       394
#                                        publisher       0.55      0.09      0.15        67
#                                     record label       0.97      0.16      0.27       232
#                                         religion       0.00      0.00      0.00        78
#                                      replaced by       0.00      0.00      0.00        10
#                                         replaces       0.00      0.00      0.00        10
#                                        residence       0.00      0.00      0.00         6
#                                     screenwriter       0.00      0.00      0.00        31
#                                   separated from       0.00      0.00      0.00         2
#                                           series       0.50      0.03      0.06        63
#                                          sibling       0.00      0.00      0.00       129
#                                      sister city       0.00      0.00      0.00         2
#                                           spouse       0.00      0.00      0.00        80
#                                       start time       0.38      0.16      0.23        31
#                                      subclass of       0.00      0.00      0.00        36
#                                       subsidiary       0.00      0.00      0.00        29
#                             territory claimed by       0.00      0.00      0.00        10
#                                    work location       0.00      0.00      0.00        19
#
#                                         accuracy                           0.36     11430
#                                        macro avg       0.25      0.10      0.11     11430
#                                     weighted avg       0.43      0.36      0.26     11430
# c:\Users\chira\anaconda3\envs\docred\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\chira\anaconda3\envs\docred\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\chira\anaconda3\envs\docred\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
